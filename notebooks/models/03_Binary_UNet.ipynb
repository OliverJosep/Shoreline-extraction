# %%
import sys
import os
import matplotlib.pyplot as plt

# Add the src directory to the path. TEMPORARY FIX
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

from models.unet.unet import UNet
from src.models.data_management.cnn_formes import CNNFormes
from src.data_processing.dataset_loader import CoastData
from src.models.data_management.data_loader import DataLoaderManager

import cv2

# %%
# Load the data to split it and save it to a dict
path = os.path.abspath(os.path.join(os.getcwd(), "../../data/patchify_shoreline/"))
# data = CoastData(data_path=path)

# data_split = data.split_data()

# %%
unet = UNet(num_classes=1, experiment_name="test_experiments", use_mlflow=False)

# %%
# Load the data to the model
data = unet.load_data(path, CNNFormes)

# %%
# Total non-shoreline pixels:  1155193552
# Total shoreline pixels:  4269360
# Total pixels:  1159462912
# Shoreline percentage:  0.3682187636890968

total_pixels = 1159462912
shoreline_pixels = 4269360

# Calculate the class weight
weight = total_pixels / shoreline_pixels

print(weight)
# Out:
# 271.577686585343

# %%
artifact_path = os.path.abspath(os.path.join(path, "../../artifacts/"))
print(artifact_path)
# Train the model
# unet.train(epochs=2, loss_function_name="BCEWithLogitsLoss", weight=weight, artifact_path=artifact_path)
# Out:
# /Users/josep/Documents/SOCIB/Shoreline-extraction/artifacts

# %% [markdown]
# # Predictions

# %%
import numpy as np
data = DataLoaderManager.load_data(os.path.abspath(os.path.join(os.getcwd(), "../../data/patchify_shoreline/")))
index = 1
img_path = data["test"]['images'][index]
mask_path = data["test"]['masks'][index]

unet.load_model("../../prova/2025-02-14-09-35-29.pth")

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

pred = unet.predict(img)

print(np.unique(mask, return_counts=True))
print(np.unique(pred, return_counts=True))


fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(img)
ax[1].imshow(mask)
ax[2].imshow(pred.squeeze())

plt.show()
# Out:
# (array([0, 1], dtype=uint8), array([65195,   341]))
# (array([0., 1.], dtype=float32), array([64734,   802]))

# %% [markdown]
# # DiceLoss

# %%
# Load the data to split it and save it to a dict
path = os.path.abspath(os.path.join(os.getcwd(), "../../data/patchify_shoreline/"))

# %%
unet = UNet(num_classes=1, experiment_name="test_experiments", use_mlflow=True)
# Load the data to the model
data = unet.load_data(path, CNNFormes)

# %%
artifact_path = os.path.abspath(os.path.join(path, "../../artifacts/"))

# Train the model without weight
unet.train(epochs=50, loss_function_name="DiceLoss", weight=None, artifact_path=artifact_path)
# Out:
# Creating folders for the artifacts at /srv/Shoreline-extraction/artifacts/2025-02-18-15-57-57
# Epoch 1/50
# 	train_accuracy: 0.95684308
# 	train_f1: 0.02132904
# 	train_precision: 0.01163543
# 	train_recall: 0.12780474
# 	train_confusion_matrix: tensor([[0.9599, 0.0401],
#         [0.8722, 0.1278]])
# 	train_loss: 0.9684708862150869
#
# 	validation_accuracy: 0.9919585
# 	validation_f1: 0.03591026
# 	validation_precision: 0.03219223
# 	validation_recall: 0.04059925
# 	validation_confusion_matrix: tensor([[0.9955, 0.0045],
#         [0.9594, 0.0406]])
# 	validation_loss: 0.9694920648816484
#
# Epoch 2/50
# 	train_accuracy: 0.97372246
# 	train_f1: 0.03088743
# 	train_precision: 0.01786854
# 	train_recall: 0.11380495
# 	train_confusion_matrix: tensor([[0.9769, 0.0231],
#         [0.8862, 0.1138]])
# 	train_loss: 0.9483912859809014
#
# 	validation_accuracy: 0.99061203
# 	validation_f1: 0.05595618
# 	validation_precision: 0.04447563
# 	validation_recall: 0.075426
# 	validation_confusion_matrix: tensor([[0.9940, 0.0060],
#         [0.9246, 0.0754]])
# 	validation_loss: 0.9618608920552612
#
# Epoch 3/50
# 	train_accuracy: 0.98014998
# 	train_f1: 0.04009113
# 	train_precision: 0.02438423
# 	train_recall: 0.11265926
# 	train_confusion_matrix: tensor([[0.9834, 0.0166],
#         [0.8873, 0.1127]])
# 	train_loss: 0.9325369336015434
#
# 	validation_accuracy: 0.99131101
# 	validation_f1: 0.07252325
# 	validation_precision: 0.0598098
# 	validation_recall: 0.09210058
# 	validation_confusion_matrix: tensor([[0.9946, 0.0054],
#         [0.9079, 0.0921]])
# 	validation_loss: 0.9527225107808638
#
# Epoch 4/50
# 	train_accuracy: 0.98348379
# 	train_f1: 0.04837194
# 	train_precision: 0.03069286
# 	train_recall: 0.11408436
# 	train_confusion_matrix: tensor([[0.9867, 0.0133],
#         [0.8859, 0.1141]])
# 	train_loss: 0.9213533302468638
#
# 	validation_accuracy: 0.99156982
# 	validation_f1: 0.08363871
# 	validation_precision: 0.06980796
# 	validation_recall: 0.104304
# 	validation_confusion_matrix: tensor([[0.9949, 0.0051],
#         [0.8957, 0.1043]])
# 	validation_loss: 0.9460713104829529
#
# Epoch 5/50
# 	train_accuracy: 0.9855389
# 	train_f1: 0.05592052
# 	train_precision: 0.03679936
# 	train_recall: 0.11640535
# 	train_confusion_matrix: tensor([[0.9887, 0.0113],
#         [0.8836, 0.1164]])
# 	train_loss: 0.9124197887605237
#
# 	validation_accuracy: 0.99217707
# 	validation_f1: 0.08834612
# 	validation_precision: 0.07747518
# 	validation_recall: 0.1027657
# 	validation_confusion_matrix: tensor([[0.9955, 0.0045],
#         [0.8972, 0.1028]])
# 	validation_loss: 0.9423252517281614
#
# Epoch 6/50
# 	train_accuracy: 0.98690969
# 	train_f1: 0.06299855
# 	train_precision: 0.04275992
# 	train_recall: 0.11961196
# 	train_confusion_matrix: tensor([[0.9901, 0.0099],
#         [0.8804, 0.1196]])
# 	train_loss: 0.9048858961238656
#
# 	validation_accuracy: 0.99254054
# 	validation_f1: 0.09197269
# 	validation_precision: 0.08346555
# 	validation_recall: 0.10241082
# 	validation_confusion_matrix: tensor([[0.9958, 0.0042],
#         [0.8976, 0.1024]])
# 	validation_loss: 0.938445437817552
#
# Epoch 7/50
# 	train_accuracy: 0.98790222
# 	train_f1: 0.0696165
# 	train_precision: 0.04854365
# 	train_recall: 0.12301908
# 	train_confusion_matrix: tensor([[0.9911, 0.0089],
#         [0.8770, 0.1230]])
# 	train_loss: 0.8979444395561922
#
# 	validation_accuracy: 0.99278671
# 	validation_f1: 0.09798393
# 	validation_precision: 0.09094351
# 	validation_recall: 0.10620589
# 	validation_confusion_matrix: tensor([[0.9961, 0.0039],
#         [0.8938, 0.1062]])
# 	validation_loss: 0.9344912115881808
#
# Epoch 8/50
# 	train_accuracy: 0.98864359
# 	train_f1: 0.07583427
# 	train_precision: 0.05412131
# 	train_recall: 0.12664184
# 	train_confusion_matrix: tensor([[0.9918, 0.0082],
#         [0.8734, 0.1266]])
# 	train_loss: 0.8915658896873074
#
# 	validation_accuracy: 0.99305433
# 	validation_f1: 0.10286716
# 	validation_precision: 0.09824716
# 	validation_recall: 0.10794312
# 	validation_confusion_matrix: tensor([[0.9963, 0.0037],
#         [0.8921, 0.1079]])
# 	validation_loss: 0.9309157308747326
#
# Epoch 9/50
# 	train_accuracy: 0.98923033
# 	train_f1: 0.08157945
# 	train_precision: 0.05943755
# 	train_recall: 0.13001204
# 	train_confusion_matrix: tensor([[0.9924, 0.0076],
#         [0.8700, 0.1300]])
# 	train_loss: 0.885956896411048
#
# 	validation_accuracy: 0.99322337
# 	validation_f1: 0.10815103
# 	validation_precision: 0.10510363
# 	validation_recall: 0.11138041
# 	validation_confusion_matrix: tensor([[0.9965, 0.0035],
#         [0.8886, 0.1114]])
# 	validation_loss: 0.9269070399352928
#
# Epoch 10/50
# 	train_accuracy: 0.98970127
# 	train_f1: 0.08689676
# 	train_precision: 0.06448559
# 	train_recall: 0.13318284
# 	train_confusion_matrix: tensor([[0.9929, 0.0071],
#         [0.8668, 0.1332]])
# 	train_loss: 0.8809290364788425
#
# 	validation_accuracy: 0.99320626
# 	validation_f1: 0.11315649
# 	validation_precision: 0.10913672
# 	validation_recall: 0.11748371
# 	validation_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8825, 0.1175]])
# 	validation_loss: 0.9230946024079129
#
# Epoch 11/50
# 	train_accuracy: 0.99010438
# 	train_f1: 0.09193811
# 	train_precision: 0.06940431
# 	train_recall: 0.13613907
# 	train_confusion_matrix: tensor([[0.9933, 0.0067],
#         [0.8639, 0.1361]])
# 	train_loss: 0.876240027342374
#
# 	validation_accuracy: 0.99316049
# 	validation_f1: 0.1180738
# 	validation_precision: 0.11259276
# 	validation_recall: 0.12411578
# 	validation_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8759, 0.1241]])
# 	validation_loss: 0.9194068364624328
#
# Epoch 12/50
# 	train_accuracy: 0.99043661
# 	train_f1: 0.09670389
# 	train_precision: 0.0741092
# 	train_recall: 0.13911952
# 	train_confusion_matrix: tensor([[0.9936, 0.0064],
#         [0.8609, 0.1391]])
# 	train_loss: 0.871924492761653
#
# 	validation_accuracy: 0.99322695
# 	validation_f1: 0.12189209
# 	validation_precision: 0.11680755
# 	validation_recall: 0.12743942
# 	validation_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8726, 0.1274]])
# 	validation_loss: 0.9162163049387176
#
# Epoch 13/50
# 	train_accuracy: 0.99071127
# 	train_f1: 0.10105462
# 	train_precision: 0.07846729
# 	train_recall: 0.14190237
# 	train_confusion_matrix: tensor([[0.9938, 0.0062],
#         [0.8581, 0.1419]])
# 	train_loss: 0.8681835188404207
#
# 	validation_accuracy: 0.99329954
# 	validation_f1: 0.12550668
# 	validation_precision: 0.12100792
# 	validation_recall: 0.1303529
# 	validation_confusion_matrix: tensor([[0.9965, 0.0035],
#         [0.8696, 0.1304]])
# 	validation_loss: 0.9133248447832478
#
# Epoch 14/50
# 	train_accuracy: 0.99094701
# 	train_f1: 0.10530269
# 	train_precision: 0.08272753
# 	train_recall: 0.14482272
# 	train_confusion_matrix: tensor([[0.9941, 0.0059],
#         [0.8552, 0.1448]])
# 	train_loss: 0.8645690003682941
#
# 	validation_accuracy: 0.99335003
# 	validation_f1: 0.12924974
# 	validation_precision: 0.12499525
# 	validation_recall: 0.13380402
# 	validation_confusion_matrix: tensor([[0.9965, 0.0035],
#         [0.8662, 0.1338]])
# 	validation_loss: 0.9103382232887327
#
# Epoch 15/50
# 	train_accuracy: 0.99115127
# 	train_f1: 0.10933845
# 	train_precision: 0.086809
# 	train_recall: 0.14766067
# 	train_confusion_matrix: tensor([[0.9943, 0.0057],
#         [0.8523, 0.1477]])
# 	train_loss: 0.8612295948920712
#
# 	validation_accuracy: 0.99337125
# 	validation_f1: 0.13290766
# 	validation_precision: 0.12841885
# 	validation_recall: 0.13772163
# 	validation_confusion_matrix: tensor([[0.9965, 0.0035],
#         [0.8623, 0.1377]])
# 	validation_loss: 0.9075295920465507
#
# Epoch 16/50
# 	train_accuracy: 0.99133348
# 	train_f1: 0.11315307
# 	train_precision: 0.09072831
# 	train_recall: 0.15030248
# 	train_confusion_matrix: tensor([[0.9944, 0.0056],
#         [0.8497, 0.1503]])
# 	train_loss: 0.8580604765588238
#
# 	validation_accuracy: 0.99337238
# 	validation_f1: 0.13545918
# 	validation_precision: 0.13055319
# 	validation_recall: 0.14074831
# 	validation_confusion_matrix: tensor([[0.9965, 0.0035],
#         [0.8593, 0.1407]])
# 	validation_loss: 0.9054271216710769
#
# Epoch 17/50
# 	train_accuracy: 0.99149841
# 	train_f1: 0.11678031
# 	train_precision: 0.09450229
# 	train_recall: 0.15280224
# 	train_confusion_matrix: tensor([[0.9946, 0.0054],
#         [0.8472, 0.1528]])
# 	train_loss: 0.855051418291776
#
# 	validation_accuracy: 0.99345845
# 	validation_f1: 0.13770865
# 	validation_precision: 0.13402368
# 	validation_recall: 0.14160198
# 	validation_confusion_matrix: tensor([[0.9966, 0.0034],
#         [0.8584, 0.1416]])
# 	validation_loss: 0.9036021501674657
#
# Epoch 18/50
# 	train_accuracy: 0.99164706
# 	train_f1: 0.12022118
# 	train_precision: 0.09812722
# 	train_recall: 0.15515535
# 	train_confusion_matrix: tensor([[0.9947, 0.0053],
#         [0.8448, 0.1552]])
# 	train_loss: 0.8522190283447184
#
# 	validation_accuracy: 0.99350595
# 	validation_f1: 0.14015183
# 	validation_precision: 0.1369895
# 	validation_recall: 0.14346363
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8565, 0.1435]])
# 	validation_loss: 0.9015776076737572
#
# Epoch 19/50
# 	train_accuracy: 0.99178153
# 	train_f1: 0.1234842
# 	train_precision: 0.10159492
# 	train_recall: 0.15739618
# 	train_confusion_matrix: tensor([[0.9949, 0.0051],
#         [0.8426, 0.1574]])
# 	train_loss: 0.8495029710144665
#
# 	validation_accuracy: 0.99352914
# 	validation_f1: 0.1426612
# 	validation_precision: 0.13953368
# 	validation_recall: 0.14593205
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8541, 0.1459]])
# 	validation_loss: 0.8994133929520398
#
# Epoch 20/50
# 	train_accuracy: 0.99190426
# 	train_f1: 0.12664071
# 	train_precision: 0.10497129
# 	train_recall: 0.15958346
# 	train_confusion_matrix: tensor([[0.9950, 0.0050],
#         [0.8404, 0.1596]])
# 	train_loss: 0.8468456971222355
#
# 	validation_accuracy: 0.99356985
# 	validation_f1: 0.14470679
# 	validation_precision: 0.14207374
# 	validation_recall: 0.14743926
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8526, 0.1474]])
# 	validation_loss: 0.897481671097052
#
# 	train_accuracy: 0.99201423
# 	train_f1: 0.12964572
# 	train_precision: 0.1081946
# 	train_recall: 0.16170566
# 	train_confusion_matrix: tensor([[0.9951, 0.0049],
#         [0.8383, 0.1617]])
# 	train_loss: 0.8444398718971627
#
# 	validation_accuracy: 0.99356353
# 	validation_f1: 0.14686082
# 	validation_precision: 0.14371277
# 	validation_recall: 0.15014994
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8499, 0.1502]])
# 	validation_loss: 0.8956679577098995
#
# Epoch 22/50
# 	train_accuracy: 0.99211991
# 	train_f1: 0.13244857
# 	train_precision: 0.11129232
# 	train_recall: 0.16353552
# 	train_confusion_matrix: tensor([[0.9952, 0.0048],
#         [0.8365, 0.1635]])
# 	train_loss: 0.842136712095255
#
# 	validation_accuracy: 0.99354422
# 	validation_f1: 0.14897491
# 	validation_precision: 0.14503436
# 	validation_recall: 0.1531357
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8469, 0.1531]])
# 	validation_loss: 0.8938339183552184
#
# Epoch 23/50
# 	train_accuracy: 0.99221665
# 	train_f1: 0.13518506
# 	train_precision: 0.1143072
# 	train_recall: 0.16539317
# 	train_confusion_matrix: tensor([[0.9953, 0.0047],
#         [0.8346, 0.1654]])
# 	train_loss: 0.8399393983041087
#
# 	validation_accuracy: 0.99356991
# 	validation_f1: 0.15084672
# 	validation_precision: 0.14712763
# 	validation_recall: 0.15475892
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8452, 0.1548]])
# 	validation_loss: 0.8921822408111973
#
# Epoch 24/50
# 	train_accuracy: 0.99230343
# 	train_f1: 0.13786684
# 	train_precision: 0.11725029
# 	train_recall: 0.16727959
# 	train_confusion_matrix: tensor([[0.9953, 0.0047],
#         [0.8327, 0.1673]])
# 	train_loss: 0.837784779142308
#
# 	validation_accuracy: 0.99359602
# 	validation_f1: 0.15249689
# 	validation_precision: 0.1490396
# 	validation_recall: 0.1561185
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8439, 0.1561]])
# 	validation_loss: 0.8907280337531822
#
# Epoch 25/50
# 	train_accuracy: 0.99238276
# 	train_f1: 0.14042436
# 	train_precision: 0.12007493
# 	train_recall: 0.16907768
# 	train_confusion_matrix: tensor([[0.9954, 0.0046],
#         [0.8309, 0.1691]])
# 	train_loss: 0.8357138034574447
#
# 	validation_accuracy: 0.9935686
# 	validation_f1: 0.15408427
# 	validation_precision: 0.14973152
# 	validation_recall: 0.15869807
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8413, 0.1587]])
# 	validation_loss: 0.889085441380065
#
# Epoch 26/50
# 	train_accuracy: 0.99246258
# 	train_f1: 0.14287332
# 	train_precision: 0.12283219
# 	train_recall: 0.17072886
# 	train_confusion_matrix: tensor([[0.9955, 0.0045],
#         [0.8293, 0.1707]])
# 	train_loss: 0.8336922611373826
#
# 	validation_accuracy: 0.99362338
# 	validation_f1: 0.15506637
# 	validation_precision: 0.15176347
# 	validation_recall: 0.15851665
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8415, 0.1585]])
# 	validation_loss: 0.8882626344777548
#
# Epoch 27/50
# 	train_accuracy: 0.99253827
# 	train_f1: 0.14527236
# 	train_precision: 0.12555896
# 	train_recall: 0.17232846
# 	train_confusion_matrix: tensor([[0.9956, 0.0044],
#         [0.8277, 0.1723]])
# 	train_loss: 0.8317055241295371
#
# 	validation_accuracy: 0.99364936
# 	validation_f1: 0.15653218
# 	validation_precision: 0.15354431
# 	validation_recall: 0.15963891
# 	validation_confusion_matrix: tensor([[0.9967, 0.0033],
#         [0.8404, 0.1596]])
# 	validation_loss: 0.8870914813180415
#
# Epoch 28/50
# 	train_accuracy: 0.99260795
# 	train_f1: 0.14757392
# 	train_precision: 0.12817441
# 	train_recall: 0.17389308
# 	train_confusion_matrix: tensor([[0.9956, 0.0044],
#         [0.8261, 0.1739]])
# 	train_loss: 0.8298169383859854
#
# 	validation_accuracy: 0.99367017
# 	validation_f1: 0.15738991
# 	validation_precision: 0.15473528
# 	validation_recall: 0.16013741
# 	validation_confusion_matrix: tensor([[0.9968, 0.0032],
#         [0.8399, 0.1601]])
# 	validation_loss: 0.8860758060147551
#
# Epoch 29/50
# 	train_accuracy: 0.99267411
# 	train_f1: 0.14977431
# 	train_precision: 0.1306975
# 	train_recall: 0.175372
# 	train_confusion_matrix: tensor([[0.9957, 0.0043],
#         [0.8246, 0.1754]])
# 	train_loss: 0.8280425232986984
#
# 	validation_accuracy: 0.99368554
# 	validation_f1: 0.1586632
# 	validation_precision: 0.15612736
# 	validation_recall: 0.16128303
# 	validation_confusion_matrix: tensor([[0.9968, 0.0032],
#         [0.8387, 0.1613]])
# 	validation_loss: 0.8848158120830004
#
# Epoch 30/50
# 	train_accuracy: 0.99273574
# 	train_f1: 0.15197112
# 	train_precision: 0.13320903
# 	train_recall: 0.17688483
# 	train_confusion_matrix: tensor([[0.9957, 0.0043],
#         [0.8231, 0.1769]])
# 	train_loss: 0.8262179589451
#
# 	validation_accuracy: 0.99370748
# 	validation_f1: 0.15990117
# 	validation_precision: 0.15765412
# 	validation_recall: 0.16221347
# 	validation_confusion_matrix: tensor([[0.9968, 0.0032],
#         [0.8378, 0.1622]])
# 	validation_loss: 0.8836402572298122
#
# Epoch 31/50
# 	train_accuracy: 0.99279612
# 	train_f1: 0.15409659
# 	train_precision: 0.13566625
# 	train_recall: 0.17832156
# 	train_confusion_matrix: tensor([[0.9958, 0.0042],
#         [0.8217, 0.1783]])
# 	train_loss: 0.8244427767727799
#
# 	validation_accuracy: 0.99372756
# 	validation_f1: 0.16080543
# 	validation_precision: 0.15887545
# 	validation_recall: 0.16278324
# 	validation_confusion_matrix: tensor([[0.9968, 0.0032],
#         [0.8372, 0.1628]])
# 	validation_loss: 0.8827552491166334
#
# Epoch 32/50
# 	train_accuracy: 0.99285263
# 	train_f1: 0.15615161
# 	train_precision: 0.13805155
# 	train_recall: 0.17971379
# 	train_confusion_matrix: tensor([[0.9959, 0.0041],
#         [0.8203, 0.1797]])
# 	train_loss: 0.8227254406314704
#
# 	validation_accuracy: 0.99374288
# 	validation_f1: 0.16168983
# 	validation_precision: 0.15996636
# 	validation_recall: 0.16345127
# 	validation_confusion_matrix: tensor([[0.9968, 0.0032],
#         [0.8365, 0.1635]])
# 	validation_loss: 0.8817838017167144
#
# Epoch 33/50
# 	train_accuracy: 0.99290496
# 	train_f1: 0.1581504
# 	train_precision: 0.14036362
# 	train_recall: 0.18109901
# 	train_confusion_matrix: tensor([[0.9959, 0.0041],
#         [0.8189, 0.1811]])
# 	train_loss: 0.8210624863115573
#
# 	validation_accuracy: 0.99379015
# 	validation_f1: 0.1623379
# 	validation_precision: 0.16168062
# 	validation_recall: 0.16300097
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8370, 0.1630]])
# 	validation_loss: 0.8812579709071608
#
# Epoch 34/50
# 	train_accuracy: 0.9929558
# 	train_f1: 0.1601225
# 	train_precision: 0.14265198
# 	train_recall: 0.18246916
# 	train_confusion_matrix: tensor([[0.9959, 0.0041],
#         [0.8175, 0.1825]])
# 	train_loss: 0.819423339561448
#
# 	validation_accuracy: 0.99382222
# 	validation_f1: 0.16303182
# 	validation_precision: 0.16308101
# 	validation_recall: 0.16298315
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8370, 0.1630]])
# 	validation_loss: 0.880669943387438
#
# Epoch 35/50
# 	train_accuracy: 0.99300385
# 	train_f1: 0.16202956
# 	train_precision: 0.14487056
# 	train_recall: 0.18379912
# 	train_confusion_matrix: tensor([[0.9960, 0.0040],
#         [0.8162, 0.1838]])
# 	train_loss: 0.8178377669659628
#
# 	validation_accuracy: 0.99380302
# 	validation_f1: 0.16412199
# 	validation_precision: 0.16346164
# 	validation_recall: 0.16478823
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8352, 0.1648]])
# 	validation_loss: 0.8796277982848031
#
# Epoch 36/50
# 	train_accuracy: 0.99304903
# 	train_f1: 0.16387266
# 	train_precision: 0.14702061
# 	train_recall: 0.18508749
# 	train_confusion_matrix: tensor([[0.9960, 0.0040],
#         [0.8149, 0.1851]])
# 	train_loss: 0.8163083573737879
#
# 	validation_accuracy: 0.99382836
# 	validation_f1: 0.16504858
# 	validation_precision: 0.16487229
# 	validation_recall: 0.16522582
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8348, 0.1652]])
# 	validation_loss: 0.8787449956944146
#
# Epoch 37/50
# 	train_accuracy: 0.99309397
# 	train_f1: 0.16571046
# 	train_precision: 0.14917752
# 	train_recall: 0.18636449
# 	train_confusion_matrix: tensor([[0.9961, 0.0039],
#         [0.8136, 0.1864]])
# 	train_loss: 0.8147371407311796
#
# 	validation_accuracy: 0.99379629
# 	validation_f1: 0.16582803
# 	validation_precision: 0.16465262
# 	validation_recall: 0.16702098
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8330, 0.1670]])
# 	validation_loss: 0.8779382215701412
#
# Epoch 38/50
# 	train_accuracy: 0.99313569
# 	train_f1: 0.16745706
# 	train_precision: 0.15124168
# 	train_recall: 0.18756704
# 	train_confusion_matrix: tensor([[0.9961, 0.0039],
#         [0.8124, 0.1876]])
# 	train_loss: 0.8132677123987816
#
# 	validation_accuracy: 0.993801
# 	validation_f1: 0.16662614
# 	validation_precision: 0.16542572
# 	validation_recall: 0.16784476
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8322, 0.1678]])
# 	validation_loss: 0.877187769380062
#
# Epoch 39/50
# 	train_accuracy: 0.99317861
# 	train_f1: 0.16916537
# 	train_precision: 0.15329655
# 	train_recall: 0.18869926
# 	train_confusion_matrix: tensor([[0.9962, 0.0038],
#         [0.8113, 0.1887]])
# 	train_loss: 0.8118061362996981
#
# 	validation_accuracy: 0.99380755
# 	validation_f1: 0.16746424
# 	validation_precision: 0.16625415
# 	validation_recall: 0.16869266
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8313, 0.1687]])
# 	validation_loss: 0.8764057005277461
#
# Epoch 40/50
# 	train_accuracy: 0.99325627
# 	train_f1: 0.17248674
# 	train_precision: 0.15728289
# 	train_recall: 0.19094539
# 	train_confusion_matrix: tensor([[0.9962, 0.0038],
#         [0.8091, 0.1909]])
# 	train_loss: 0.8089878665622438
#
# 	validation_accuracy: 0.99380928
# 	validation_f1: 0.16871901
# 	validation_precision: 0.1673189
# 	validation_recall: 0.1701434
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8299, 0.1701]])
# 	validation_loss: 0.874823382089975
#
# Epoch 42/50
# 	train_accuracy: 0.99329209
# 	train_f1: 0.17411985
# 	train_precision: 0.15921843
# 	train_recall: 0.19209923
# 	train_confusion_matrix: tensor([[0.9963, 0.0037],
#         [0.8079, 0.1921]])
# 	train_loss: 0.8076049906830267
#
# 	validation_accuracy: 0.99382383
# 	validation_f1: 0.16951716
# 	validation_precision: 0.16834711
# 	validation_recall: 0.17070417
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8293, 0.1707]])
# 	validation_loss: 0.8741164286957042
#
# Epoch 43/50
# 	train_accuracy: 0.99333489
# 	train_f1: 0.17574723
# 	train_precision: 0.16118115
# 	train_recall: 0.19320804
# 	train_confusion_matrix: tensor([[0.9963, 0.0037],
#         [0.8068, 0.1932]])
# 	train_loss: 0.8062071617706682
#
# 	validation_accuracy: 0.99384576
# 	validation_f1: 0.17012894
# 	validation_precision: 0.16942483
# 	validation_recall: 0.17083949
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8292, 0.1708]])
# 	validation_loss: 0.873483116992032
#
# Epoch 44/50
# 	train_accuracy: 0.99338329
# 	train_f1: 0.17733848
# 	train_precision: 0.16310015
# 	train_recall: 0.19430117
# 	train_confusion_matrix: tensor([[0.9963, 0.0037],
#         [0.8057, 0.1943]])
# 	train_loss: 0.8048322526415772
#
# 	validation_accuracy: 0.99387002
# 	validation_f1: 0.17062172
# 	validation_precision: 0.17049401
# 	validation_recall: 0.17075019
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8292, 0.1708]])
# 	validation_loss: 0.8730525671884093
#
# Epoch 45/50
# 	train_accuracy: 0.99343079
# 	train_f1: 0.17888804
# 	train_precision: 0.16500255
# 	train_recall: 0.19532566
# 	train_confusion_matrix: tensor([[0.9963, 0.0037],
#         [0.8047, 0.1953]])
# 	train_loss: 0.8034778174841276
#
# 	validation_accuracy: 0.99387121
# 	validation_f1: 0.17130855
# 	validation_precision: 0.17106645
# 	validation_recall: 0.17155194
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8284, 0.1716]])
# 	validation_loss: 0.8723241212501066
#
# Epoch 46/50
# 	train_accuracy: 0.99347425
# 	train_f1: 0.18040374
# 	train_precision: 0.16684699
# 	train_recall: 0.19635879
# 	train_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8036, 0.1964]])
# 	train_loss: 0.8021818574765621
#
# 	validation_accuracy: 0.99387091
# 	validation_f1: 0.1717941
# 	validation_precision: 0.17142542
# 	validation_recall: 0.17216495
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8278, 0.1722]])
# 	validation_loss: 0.8716930732726113
#
# Epoch 47/50
# 	train_accuracy: 0.99352068
# 	train_f1: 0.18190004
# 	train_precision: 0.16870257
# 	train_recall: 0.19733791
# 	train_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8027, 0.1973]])
# 	train_loss: 0.800867865358875
#
# 	validation_accuracy: 0.99389189
# 	validation_f1: 0.17221656
# 	validation_precision: 0.17236336
# 	validation_recall: 0.17207061
# 	validation_confusion_matrix: tensor([[0.9969, 0.0031],
#         [0.8279, 0.1721]])
# 	validation_loss: 0.8712643712136403
#
# Epoch 48/50
# 	train_accuracy: 0.99356359
# 	train_f1: 0.18340144
# 	train_precision: 0.17050971
# 	train_recall: 0.1984022
# 	train_confusion_matrix: tensor([[0.9964, 0.0036],
#         [0.8016, 0.1984]])
# 	train_loss: 0.7995872674449798
#
# 	validation_accuracy: 0.99390292
# 	validation_f1: 0.1727656
# 	validation_precision: 0.17310202
# 	validation_recall: 0.17243119
# 	validation_confusion_matrix: tensor([[0.9970, 0.0030],
#         [0.8276, 0.1724]])
# 	validation_loss: 0.8707119189596104
#
# Early stopping triggered.
# 🏃 View run 2025-02-18-15-57-57 at: https://mlflow.cloud.imagine-ai.eu/#/experiments/134/runs/04c983c84eec437996a3d7a416f43816
# 🧪 View experiment at: https://mlflow.cloud.imagine-ai.eu/#/experiments/134

# %% [markdown]
# ## Training with weights and DiceLoss
#
# We need values between 0 and 1, so:
# $$
# w_{shoreline} = \frac{\text{Total non-shoreline pixels}}{\text{Total pixels}}
# $$
#
# $$
# w_{non-shoreline} = \frac{\text{Total shoreline pixels}}{\text{Total pixels}}
# $$
#
# And we obtain:
#
# $$
# w_{shoreline} = \frac{1155193552}{1159462912} \approx 0.9963
# $$
#
# $$
# w_{non-shoreline} = \frac{4269360}{1159462912} \approx 0.0037
# $$
#
# So, we will set a weight of 0.9963 to the positive class.

# %%
# Total non-shoreline pixels:  1155193552
# Total shoreline pixels:  4269360
# Total pixels:  1159462912
# Shoreline percentage:  0.3682187636890968
non_shoreline_pixels = 1155193552
total_pixels = 1159462912
weight = non_shoreline_pixels / total_pixels

print(weight)
# Out:
# 0.996317812363109

# %%
# Load the data to split it and save it to a dict
path = os.path.abspath(os.path.join(os.getcwd(), "../../data/patchify_shoreline/"))

unet = UNet(num_classes=1, experiment_name="test_experiments", use_mlflow=True)
# Load the data to the model
data = unet.load_data(path, CNNFormes)

# %%
artifact_path = os.path.abspath(os.path.join(path, "../../artifacts/"))

# Train the model without weight
unet.train(epochs=50, loss_function_name="DiceLoss", weight=weight, artifact_path=artifact_path)
# Out:
# Creating folders for the artifacts at /srv/Shoreline-extraction/artifacts/2025-02-19-10-28-14
# Epoch 1/50
# 	train_accuracy: 0.96384919
# 	train_f1: 0.03780825
# 	train_precision: 0.0209566
# 	train_recall: 0.19301903
# 	train_confusion_matrix: tensor([[0.9667, 0.0333],
#         [0.8070, 0.1930]])
# 	train_loss: 0.006938070726370619
#
# 	validation_accuracy: 0.98731679
# 	validation_f1: 0.07571085
# 	validation_precision: 0.05177278
# 	validation_recall: 0.14082274
# 	validation_confusion_matrix: tensor([[0.9905, 0.0095],
#         [0.8592, 0.1408]])
# 	validation_loss: 0.006965819579797768
#
# Validation loss improved from inf to 0.006966. Saving the model. Early stopping counter: 0/25
# Epoch 2/50
