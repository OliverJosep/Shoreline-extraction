# %%
import sys
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Add the src directory to the path. TEMPORARY FIX
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../..")))

from src.data_processing.dataset_loader import CoastData

# %%
data_path = os.path.abspath(os.path.join(os.getcwd(), "../../../data/SCLabels_oblique_v1.0.0/"))

# Load the data, all the different stations
data = CoastData(data_path)
station_names = data.get_station_names()

CLASS_MAP = {
    0: "NoData",
    25: "NotClassified",
    75: "Landwards",
    150: "Seawards",
    255: "Shoreline"
}

total_pixels_station_and_class = {station: {cls: 0 for cls in CLASS_MAP.keys()} for station in station_names} 
total_pixels_station = {station: 0 for station in station_names}
total_pixels_global = {cls: 0 for cls in CLASS_MAP.keys()}
print(total_pixels_station_and_class)

station_shapes = {station: {'heights': [], 'widths': []} for station in station_names}
# Out:
# CoastData: global - 1717 images
# {'agrelo': {0: 0, 25: 0, 75: 0, 150: 0, 255: 0}, 'arenaldentem': {0: 0, 25: 0, 75: 0, 150: 0, 255: 0}, 'cadiz': {0: 0, 25: 0, 75: 0, 150: 0, 255: 0}, 'cies': {0: 0, 25: 0, 75: 0, 150: 0, 255: 0}, 'samarador': {0: 0, 25: 0, 75: 0, 150: 0, 255: 0}}

# %%
for station in station_names:
    # print(station)
    station_data = data.get_images(station)
    print(f"\nStation: {station}")
    print(f"Number of images in station {station}: {len(station_data)}")

    for image_data in station_data:

        mask = cv2.imread(image_data['mask'], cv2.IMREAD_GRAYSCALE)
        total_pixels = mask.shape[0] * mask.shape[1]
        total_pixels_station[station] += total_pixels
        
        classes, count = np.unique(mask, return_counts=True)
        for cls, cnt in zip(classes, count):
            percentage = (cnt / total_pixels) * 100
            total_pixels_station_and_class[station][cls] += cnt
            total_pixels_global[cls] += cnt
            
        
        height, width = mask.shape
        station_shapes[station]['heights'].append(height)
        station_shapes[station]['widths'].append(width)

    for cls, cnt in total_pixels_station_and_class[station].items():
        percentage = (cnt / total_pixels_station[station]) * 100 if total_pixels_station[station] > 0 else 0
        print(f"Class {CLASS_MAP[cls]}: {cnt} pixels ({percentage:.2f}%)")

    heights = station_shapes[station]['heights']
    widths = station_shapes[station]['widths']
    print(f"Image heights in station {station}: min={min(heights)}, max={max(heights)}, mean={np.mean(heights):.2f}, std={np.std(heights):.2f}")
    print(f"Image widths in station {station}: min={min(widths)}, max={max(widths)}, mean={np.mean(widths):.2f}, std={np.std(widths):.2f}")

print("\nGlobal statistics:")
for cls, cnt in total_pixels_global.items():
    total_pixels = sum(total_pixels_global.values())
    percentage = (cnt / total_pixels) * 100 if total_pixels > 0 else 0
    print(f"Class {CLASS_MAP[cls]}: {cnt} pixels ({percentage:.2f}%)")
# Out:
# Station: agrelo
# Number of images in station agrelo: 244
# Class NoData: 56138600 pixels (4.00%)
# Class NotClassified: 38923861 pixels (2.78%)
# Class Landwards: 713309280 pixels (50.86%)
# Class Seawards: 593004472 pixels (42.28%)
# Class Shoreline: 1084587 pixels (0.08%)
# Image heights in station agrelo: min=508, max=2603, mean=690.84, std=175.83
# Image widths in station agrelo: min=8320, max=8320, mean=8320.00, std=0.00
#
# Station: arenaldentem
# Number of images in station arenaldentem: 40
# Class NoData: 3005750 pixels (3.94%)
# Class NotClassified: 3087721 pixels (4.05%)
# Class Landwards: 19333930 pixels (25.36%)
# Class Seawards: 50699165 pixels (66.51%)
# Class Shoreline: 105434 pixels (0.14%)
# Image heights in station arenaldentem: min=287, max=1021, mean=476.45, std=145.80
# Image widths in station arenaldentem: min=4000, max=4000, mean=4000.00, std=0.00
#
# Station: cadiz
# Number of images in station cadiz: 946
# Class NoData: 53041735 pixels (10.65%)
# Class NotClassified: 34533141 pixels (6.93%)
# Class Landwards: 221537960 pixels (44.48%)
# Class Seawards: 187516087 pixels (37.65%)
# Class Shoreline: 1483589 pixels (0.30%)
# Image heights in station cadiz: min=113, max=653, mean=257.10, std=97.57
# Image widths in station cadiz: min=2048, max=2048, mean=2048.00, std=0.00
#
# Station: cies
# Number of images in station cies: 430
# Class NoData: 63381970 pixels (7.14%)
# Class NotClassified: 33179636 pixels (3.74%)
# Class Landwards: 241932227 pixels (27.27%)
# Class Seawards: 547708111 pixels (61.73%)
# Class Shoreline: 1063656 pixels (0.12%)
# Image heights in station cies: min=388, max=608, mean=496.01, std=27.26
# Image widths in station cies: min=4160, max=4160, mean=4160.00, std=0.00
#
# Station: samarador
# Number of images in station samarador: 57
# Class NoData: 15689376 pixels (6.47%)
# Class NotClassified: 4236290 pixels (1.75%)
# Class Landwards: 106587291 pixels (43.92%)
# Class Seawards: 115937485 pixels (47.78%)
# Class Shoreline: 221558 pixels (0.09%)
# Image heights in station samarador: min=543, max=1972, mean=1064.35, std=303.14
# Image widths in station samarador: min=4000, max=4000, mean=4000.00, std=0.00
#
# Global statistics:
# Class NoData: 191257431 pixels (6.16%)
# Class NotClassified: 113960649 pixels (3.67%)
# Class Landwards: 1302700688 pixels (41.93%)
# Class Seawards: 1494865320 pixels (48.12%)
# Class Shoreline: 3958824 pixels (0.13%)
